# %%
import pandas as pd

df = pd.read_csv("C:\Users\itsra\Desktop\jupyter_project\netflix_titles.csv")
df.head()
df.info()
# Out:
#   Cell In[4], line 3
#     df = pd.read_csv("C:\Users\itsra\Desktop\jupyter_project\netflix_titles.csv")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
