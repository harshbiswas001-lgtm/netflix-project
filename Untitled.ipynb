# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\itsra\Desktop\jupyter_project
# ['.ipynb_checkpoints', 'netflix-project.ipynb', 'Untitled.ipynb']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\itsra\Desktop\jupyter_project
